# %%
import pandas as pd

# %%
df_precincts = pd.read_csv("precincts.csv")
df_transmissions = pd.read_csv("transmissions.csv")

# %%
df_precincts.head()
# Out:
#    Unnamed: 0 REGION PROVINCE MUNICIPALITY           BARANGAY  PRECINCT_ID  \
# 0           0  BARMM  BASILAN        AKBAR           LINONGAN      7080001
# 1           1  BARMM  BASILAN        AKBAR           LINONGAN      7080002
# 2           2  BARMM  BASILAN        AKBAR            MANGUSO      7080003
# 3           3  BARMM  BASILAN        AKBAR  UPPER SINANGKAPAN      7080004
# 4           4  BARMM  BASILAN        AKBAR           CADDAYAN      7080005
#
#    CLUSTER  CLUSTERTOTAL                 CLUSTERED_PRECINCTS  \
# 0        1           423                0012A, 0012P1, 0011A
# 1        2           411                 0011B, 0011C, 0012B
# 2        3           313         0035A, 0035C, 0035P1, 0035B
# 3        4           655  0050A, 0050B, 0050C, 0050D, 0050P1
# 4        5           479  0054A, 0055A, 0055B, 0055C, 0055P1
#
#                                        POLLINGCENTER
# 0  LINONGAN ELEMENTARY SCHOOL, BARANGAY LINONGAN,...
# ...

# %%
df_transmissions.merge(df_)
# Out:
#    Unnamed: 0  NO.  CLUSTERED  ACTUAL    RECEPTION DATETIME
# 0           0    1   31080039     304  09-May-2022 19:08:50
# 1           1    2   37470046     321  09-May-2022 19:08:51
# 2           2    3   15260038     329  09-May-2022 19:08:51
# 3           3    4   11020233     639  09-May-2022 19:08:51
# 4           4    5   10050317     581  09-May-2022 19:08:51
